# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/wines_SPA.csv')
df.head()
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
# 2   Vega Sicilia          Unico  2009     4.8         1793  Espana
# 3   Vega Sicilia          Unico  1999     4.8         1705  Espana
# 4   Vega Sicilia          Unico  1996     4.8         1309  Espana
#
#              region   price                  type  body  acidity
# 0              Toro  995.00              Toro Red   5.0      3.0
# 1    Vino de Espana  313.50           Tempranillo   4.0      2.0
# 2  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# 3  Ribera del Duero  692.96  Ribera Del Duero Red   5.0      3.0
# 4  Ribera del Duero  778.06  Ribera Del Duero Red   5.0      3.0

# %%
dicionario = pd.DataFrame([
    {
        "variavel": "winery",
        "descricao": "Vinícola do vinho",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "wine",
        "descricao": "Nome do vinho",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "year",
        "descricao": "Ano da safra do vinho",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "rating",
        "descricao": "Avaliação do vinho (1-5)",
        "tipo": "Quantitativa",
        "subtipo": "Discreta"
    },
    {
        "variavel": "num_reviews",
        "descricao": "Número de avaliações",
        "tipo": "Quantitativa",
        "subtipo": "Discreta"
    },
    {
        "variavel": "country",
        "descricao": "País de origem",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "region",
        "descricao": "Região de origem",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "price",
        "descricao": "Preço do vinho em euros",
        "tipo": "Quantitativa",
        "subtipo": "Contínua"
    },
    {
        "variavel": "type",
        "descricao": "Tipo do vinho",
        "tipo": "Qualitativa",
        "subtipo": "Nominal"
    },
    {
        "variavel": "body",
        "descricao": "Classificação do corpo do vinho (1-5)",
        "tipo": "Quantitativa",
        "subtipo": "Discreta"
    },
    {
        "variavel": "acidity",
        "descricao": "Classificação da acidez do vinho (1-5)",
        "tipo": "Quantitativa",
        "subtipo": "Discreta"
    }
])
dicionario.to_csv('../data/external/dictionary.csv', index=False)
dicionario
# Out:
#        variavel                               descricao          tipo  \
# 0        winery                       Vinícola do vinho   Qualitativa
# 1          wine                           Nome do vinho   Qualitativa
# 2          year                   Ano da safra do vinho  Quantitativa
# 3        rating                Avaliação do vinho (1-5)  Quantitativa
# 4   num_reviews                    Número de avaliações  Quantitativa
# 5       country                          País de origem   Qualitativa
# 6        region                        Região de origem   Qualitativa
# 7         price                 Preço do vinho em euros  Quantitativa
# 8          type                           Tipo do vinho   Qualitativa
# 9          body   Classificação do corpo do vinho (1-5)  Quantitativa
# 10      acidity  Classificação da acidez do vinho (1-5)  Quantitativa
#
#      subtipo
# 0    Nominal
# 1    Nominal
# 2   Contínua
# 3   Discreta
# 4   Discreta
# 5    Nominal
# 6    Nominal
# ...
